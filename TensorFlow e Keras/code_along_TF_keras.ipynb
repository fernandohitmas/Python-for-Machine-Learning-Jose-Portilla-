# %% [markdown]
# ## Regressão com Keras - Code Along

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %matplotlib inline

# %% [markdown]
# ### Leitura dos dados

# %%
caminho = '/Users/user/Documents/Pessoal/TensorFlow_FILES/DATA/kc_house_data.csv'
df = pd.read_csv(caminho)

# %% [markdown]
# ### Exploração dos dados

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Não há dados faltantes

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %% [markdown]
# ### Exploração visual

# %%
sns.displot(df, x='price')
# Out:
# /opt/homebrew/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Para o caso de dados de preços de casa, há dados aberrantes, apesar de poucos

# %%
sns.countplot(df, x='bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.select_dtypes(exclude='object').corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
sns.scatterplot(df, x='price', y='sqft_living')
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(df, y='price', x='bedrooms')
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(df, x='price', y='long')
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
sns.scatterplot(df, x='price', y='lat')
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %% [markdown]
# Uma forma de enxergar a distribuição geográfica dos preços é através de bibliotecas específicas para esse intuito. Porém utilizando o scatterplot podemos fazer o seguinte

# %%
sns.scatterplot(df, x='long', y='lat', hue='price', s=5)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
len(df)*0.01
# Out:
# 215.97

# %%
q99_df = df.sort_values('price', ascending=False).iloc[216:].copy()

# %%
sns.scatterplot(q99_df, x='long', y='lat', hue='price', s=5,
                edgecolor=None, palette='RdYlGn', alpha=0.7)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(df, x='waterfront', y='price')
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ### Feature Engineering

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id', axis=1)

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
sns.boxplot(df, x='month', y='price')
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price']
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
sns.lineplot(df.groupby('month').mean()['price'])
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
sns.lineplot(df.groupby('year').mean()['price'])
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
df = df.drop('date', axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df = df.drop('zipcode', axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: count, Length: 306, dtype: int64

# %% [markdown]
# ### Pré Processamento

# %%
X = df.drop('price', axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Criando o modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
X_train.shape
# Out:
# (15117, 19)

# %% [markdown]
# Parece fazer sentido utilizar uma camada com o número de neurons igual ao número de covariáveis

# %%
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train, y=y_train, 
          validation_data=(X_test, y_test), batch_size=128,
          epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 1s 3ms/step - loss: 430231977984.0000 - val_loss: 418870788096.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 1ms/step - loss: 428628869120.0000 - val_loss: 413365665792.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 1ms/step - loss: 406904799232.0000 - val_loss: 364819283968.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 1ms/step - loss: 310289793024.0000 - val_loss: 218680672256.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 1ms/step - loss: 154966523904.0000 - val_loss: 102870163456.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 100000956416.0000 - val_loss: 94747508736.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 1ms/step - loss: 97108410368.0000 - val_loss: 93121314816.0000
# Epoch 8/400
# ...

# %% [markdown]
# ### Avaliando o modelo

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
sns.lineplot(loss_df)
# Out:
# <Axes: >

# %% [markdown]
# Em casa de overfitting, a curva de val_loss deveria aumentar com o passar das epochs

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import explained_variance_score

# %%
pred = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 616us/step

# %%
mean_squared_error(y_test, pred)
# Out:
# 26642676546.345562

# %%
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 163225.84521559556

# %%
mean_absolute_error(y_test, pred)
# Out:
# 101213.33751567322

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
explained_variance_score(y_test,pred)
# Out:
# 0.7992804905729881

# %%
plt.scatter(x=y_test, y=pred)
plt.plot(y_test, y_test, 'r')

# %% [markdown]
# O modelo depende de outliers

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# array([[287350.34]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
